# %% [markdown]
# # 🚀 Train New Language Adapters on FREE Colab
#
# ## Train adapters for 8 new languages:
# - Sinhala (si)
# - Tibetan (bo)
# - Dzongkha (dz)
# - Pashto (ps)
# - Dari (prs)
# - Vietnamese (vi)
# - Thai (th)
# - Burmese (my)
#
# ## ⚡ Quick Start:
# 1. Upload your scraped data (Wikipedia/News JSONL files)
# 2. Choose a language to train
# 3. Run all cells
# 4. Download trained adapter
#
# ## ⏱️ Time: 2-3 hours per language on FREE T4 GPU

# %% [markdown]
# # 🚀 Gurukul Lite Enhanced Training - Phase C
#
# ## Fine-Tune BLOOMZ-560m on 21 Indian Languages
#
# ### Goals:
# 1. Fix English mixing in 7 problematic languages
# 2. Improve overall accuracy from 66.7% → 85%+
# 3. Prepare foundation for adding more languages
#
# ### Training Strategy:
# - LoRA (Low-Rank Adaptation) for parameter-efficient fine-tuning
# - Focus on curated, clean examples
# - Emphasis on staying in native script
# - 2-4 hours training on Colab Pro (V100/A100)
#
# ### Hardware Requirements:
# - **Colab Free**: Possible but risky (12hr limit, disconnections)
# - **Colab Pro ($10/month)**: Recommended (V100, more stable)
# - **Colab Pro+ ($50/month)**: Best (A100, background execution)

# %% [markdown]
# ## 📦 Step 1: Setup & Installation

# %%
# Check GPU
# !nvidia-smi

# %%
# Install required packages
# !pip install -q transformers==4.35.0
# !pip install -q peft==0.6.0
# !pip install -q datasets==2.14.0
# !pip install -q accelerate==0.24.0
# !pip install -q bitsandbytes==0.41.0
# !pip install -q sentencepiece==0.1.99

print("✅ Packages installed!")
